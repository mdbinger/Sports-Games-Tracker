# %%
# Import needed dependencies
import requests
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import re
import time
from datetime import date
from bs4 import BeautifulSoup, Comment

# %%
hof_table_list = []
hof_table_header_list = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/hof.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
hof_table = soup.select_one('#div_hof')
        
# Grab data from table and put it into the list created above
for tr in hof_table.select('tr:has(td)'):
    tds = [td.get_text(strip=True) for td in tr.select('td')]
    hof_table_list.append(tds)

for tr in hof_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    hof_table_header_list.append(ths)
    
final_hof_table_header_list = hof_table_header_list[0]
final_hof_table_header_list.pop(0)

hof_df = pd.DataFrame(hof_table_list, columns=final_hof_table_header_list)

hof_names = hof_df['Name'].to_list()

hof_table_header_list.pop(0)
hof_inducted_year = []

for item in hof_table_header_list:
    hof_inducted_year.append(item[0])

hof_df['Year Elected'] = hof_inducted_year

hof_df
# Out:
#                   Name                                            Voted By  \
# 0        Adrián Beltré  1979-Living                                  BBWAA
# 1          Todd Helton  1973-Living                                  BBWAA
# 2          Jim Leyland  1944-Living  Contemporary Baseball Era Non-Players
# 3            Joe Mauer  1983-Living                                  BBWAA
# 4         Fred McGriff  1963-Living                       Contemporary Era
# ..                 ...          ...                                    ...
# 341            Ty Cobb    1886-1961                                  BBWAA
# 342     Walter Johnson    1887-1946                                  BBWAA
# 343  Christy Mathewson    1880-1925                                  BBWAA
# 344          Babe Ruth    1895-1948                                  BBWAA
# 345       Honus Wagner    1874-1955                                  BBWAA
#
#     Inducted As  Votes % of Ballots Year Elected
# 0        Player  366.0        95.1%         2024
# 1        Player  307.0        79.7%         2024
# 2       Manager                             2024
# 3        Player  293.0        76.1%         2024
# 4        Player                             2023
# ..          ...    ...          ...          ...
# 341      Player  222.0        98.2%         1936
# 342      Player  189.0        83.6%         1936
# 343      Player  205.0        90.7%         1936
# 344      Player  215.0        95.1%         1936
# 345      Player  215.0        95.1%         1936
#
# [346 rows x 7 columns]

# %%
mvp_table_list = []
mvp_table_header_list = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/mvp.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
mvp_table = soup.select_one('#all_mvp')
        
# Grab data from table and put it into the list created above
for tr in mvp_table.select('tr:has(td)'):
    tds = [td.get_text(strip=True) for td in tr.select('td')]
    mvp_table_list.append(tds)

for tr in mvp_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    mvp_table_header_list.append(ths)
    
today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

mvp_player_list = []
mvp_year_list = []
league_list = []
counter = 2

while counter < len(mvp_table_header_list):
    if mvp_table_header_list[counter] != ['']:
        mvp_year_list.append(mvp_table_header_list[counter][0])
    counter = counter + 1
        

for item in mvp_table_list:
    if item[0] != '':
        mvp_player_list.append(item[1])
        league_list.append(item[0])
#         mvp_year_list.append(current_season)
    else:
        current_season = current_season - 1
    
mvp_df = pd.DataFrame(
    {'Year': mvp_year_list,
     'Player': mvp_player_list,
     'League': league_list
    })

mvp_df
# Out:
#      Year            Player League
# 0    2023     Shohei Ohtani     AL
# 1    2023  Ronald Acuna Jr.     NL
# 2    2022       Aaron Judge     AL
# 3    2022  Paul Goldschmidt     NL
# 4    2021     Shohei Ohtani     AL
# ..    ...               ...    ...
# 206  1913      Jake Daubert     NL
# 207  1912      Tris Speaker     AL
# 208  1912       Larry Doyle     NL
# 209  1911           Ty Cobb     AL
# 210  1911     Frank Schulte     NL
#
# [211 rows x 3 columns]

# %%
cya_table_list = []
cya_table_header_list = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/cya.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
cya_table = soup.select_one('#div_cya')
        
# Grab data from table and put it into the list created above
for tr in cya_table.select('tr:has(td)'):
    tds = [td.get_text(strip=True) for td in tr.select('td')]
    cya_table_list.append(tds)

for tr in cya_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    cya_table_header_list.append(ths)
    
today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

cya_player_list = []
cya_year_list = []
league_list = []
counter = 1

while counter < len(cya_table_header_list):
    if cya_table_header_list[counter] != ['']:
        cya_year_list.append(cya_table_header_list[counter][0])
    counter = counter + 1
        

for item in cya_table_list:
    if item[0] != '':
        cya_player_list.append(item[1])
        league_list.append(item[0])
    else:
        current_season = current_season - 1
    
cya_df = pd.DataFrame(
    {'Year': cya_year_list,
     'Player': cya_player_list,
     'League': league_list
    })

cya_df
# Out:
#      Year            Player League
# 0    2023       Gerrit Cole     AL
# 1    2023       Blake Snell     NL
# 2    2022  Justin Verlander     AL
# 3    2022   Sandy Alcántara     NL
# 4    2021        Robbie Ray     AL
# ..    ...               ...    ...
# 121  1960          Vern Law     ML
# 122  1959        Early Wynn     ML
# 123  1958        Bob Turley     ML
# 124  1957      Warren Spahn     ML
# 125  1956      Don Newcombe     ML
#
# [126 rows x 3 columns]

# %%
batting_champs_table_list = []
batting_champs_table_header_list = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/batting-titles.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
batting_champs_table = soup.select_one('#div_titleist')
        
# Grab data from table and put it into the list created above
for tr in batting_champs_table.select('tr:has(td)'):
    tds = [td.get_text(strip=True) for td in tr.select('td')]
    batting_champs_table_list.append(tds)

for tr in batting_champs_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    batting_champs_table_header_list.append(ths)
    
today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

batting_champs_player_list = []
batting_champs_year_list = []
league_list = []
counter = 0
slash_list = []

while counter < len(batting_champs_table_list[0]):
    if batting_champs_table_list[0][counter] == '':
        batting_champs_year_list.append(batting_champs_table_list[0][counter - 4])
    else:
        batting_champs_year_list.append(batting_champs_table_list[0][counter])
        
    league_list.append(batting_champs_table_list[0][counter + 1])
    batting_champs_player_list.append(batting_champs_table_list[0][counter + 2])
    slash_list.append(batting_champs_table_list[0][counter + 3])

    counter = counter + 4
            
batting_champs_df = pd.DataFrame(
    {'Year': batting_champs_year_list,
     'Player': batting_champs_player_list,
     'League': league_list,
     'Details': slash_list
    })

batting_champs_df #.sort_values('Year', ascending = False)
# Out:
#      Year        Player League                   Details
# 0    2023    Yandy Díaz     AL  TBR 137 G .330/.410/.522
# 1    2023   Luis Arráez     NL  MIA 147 G .354/.393/.469
# 2    2022   Luis Arráez     AL  MIN 144 G .316/.375/.420
# 3    2022   Jeff McNeil     NL  NYM 148 G .326/.382/.454
# 4    2021  Yuli Gurriel     AL  HOU 143 G .319/.383/.462
# ..    ...           ...    ...                       ...
# 334  1875  Deacon White     NA   BOS 80 G .367/.372/.453
# 335  1874  Levi Meyerle     NA   CHI 53 G .394/.401/.488
# 336  1873   Ross Barnes     NA   BOS 60 G .431/.465/.616
# 337  1872   Ross Barnes     NA   BOS 45 G .430/.452/.583
# 338  1871  Levi Meyerle     NA   ATH 26 G .492/.500/.700
#
# [339 rows x 4 columns]

# %%
nl_gg_table_list = []
nl_gg_table_header_list = []

today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/gold_glove_nl.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
nl_gg_table = soup.select_one('#div_award_grid')
        
# Grab data from table and put it into the list created above
for tr in nl_gg_table.select('tr:has(td)'):
 
    try:
        temp_list = []

        for td in tr.find_all('td'):
            try:
                test3 = td.find('a').get('title') 
                temp_list.append(test3)
            except:
                continue

        # test_list   
        # test_list[0] = current_season

        cleaned_list = []

        for item in temp_list:
            temp_item = re.findall(r"^(.+?),", str(item))
            cleaned_list.append(temp_item)

        cleaned_list[0] = [current_season]
        final_player_list = []

        for item2 in cleaned_list:
            final_player_list.append(item2[0])


        nl_gg_table_list.append(final_player_list)
        current_season = current_season - 1
    except:
        continue

    
for tr in nl_gg_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    nl_gg_table_header_list.append(ths)
    

nl_gg_df = pd.DataFrame(nl_gg_table_list, columns = nl_gg_table_header_list)

nl_gg_df #.sort_values('Year', ascending = False)
# Out:
#    Year & Common              P                C                1B  \
# 0           2023   Zack Wheeler   Gabriel Moreno  Christian Walker
# 1           2022      Max Fried    J.T. Realmuto  Christian Walker
# 2           2021      Max Fried  Jacob Stallings  Paul Goldschmidt
# 3           2020      Max Fried  Tucker Barnhart     Anthony Rizzo
# 4           2019   Zack Greinke    J.T. Realmuto     Anthony Rizzo
# ..           ...            ...              ...               ...
# 62          1961   Bobby Shantz    John Roseboro        Bill White
# 63          1960  Harvey Haddix     Del Crandall        Bill White
# 64          1959  Harvey Haddix     Del Crandall        Gil Hodges
# 65          1958  Harvey Haddix     Del Crandall        Gil Hodges
# 66          1957   Bobby Shantz     Sherm Lollar        Gil Hodges
#
#                  2B              3B                SS                OF  \
# 0      Nico Hoerner  Ke'Bryan Hayes    Dansby Swanson     Brenton Doyle
# 1   Brendan Rodgers   Nolan Arenado    Dansby Swanson      Mookie Betts
# 2       Tommy Edman   Nolan Arenado  Brandon Crawford     Tyler O'Neill
# 3       Kolten Wong   Nolan Arenado       Javier Báez      Mookie Betts
# 4       Kolten Wong   Nolan Arenado        Nick Ahmed      Lorenzo Cain
# ..              ...             ...               ...               ...
# 62   Bill Mazeroski       Ken Boyer       Maury Wills  Roberto Clemente
# 63   Bill Mazeroski       Ken Boyer       Ernie Banks       Henry Aaron
# 64     Charlie Neal       Ken Boyer      Roy McMillan     Jackie Brandt
# 65   Bill Mazeroski       Ken Boyer      Roy McMillan    Frank Robinson
# 66       Nellie Fox   Frank Malzone      Roy McMillan       Willie Mays
#
#                 OF                  OF              Utility  \
# 0         Ian Happ  Fernando Tatis Jr.         Ha-Seong Kim
# 1    Trent Grisham            Ian Happ      Brendan Donovan
# 2      Adam Duvall      Harrison Bader  St. Louis Cardinals
# 3    Tyler O'Neill       Trent Grisham         Chicago Cubs
# 4   Cody Bellinger       David Peralta                 None
# ..             ...                 ...                  ...
# 62     Willie Mays         Vada Pinson                 None
# 63      Wally Moon         Willie Mays                 None
# 64     Henry Aaron         Willie Mays                 None
# 65     Henry Aaron         Willie Mays                 None
# 66       Al Kaline       Minnie Miñoso                 None
#
#                    Team
# 0     Milwaukee Brewers
# 1   St. Louis Cardinals
# 2                  None
# 3                  None
# 4                  None
# ..                  ...
# 62                 None
# 63                 None
# 64                 None
# 65                 None
# 66                 None
#
# [67 rows x 12 columns]

# %%
al_gg_table_list = []
al_gg_table_header_list = []

today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/gold_glove_al.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
al_gg_table = soup.select_one('#div_award_grid')
        
# Grab data from table and put it into the list created above
for tr in al_gg_table.select('tr:has(td)'):
 
    try:
        temp_list = []

        for td in tr.find_all('td'):
            try:
                test3 = td.find('a').get('title') 
                temp_list.append(test3)
            except:
                continue

        cleaned_list = []

        for item in temp_list:
            temp_item = re.findall(r"^(.+?),", str(item))
            cleaned_list.append(temp_item)

        cleaned_list[0] = [current_season]
        final_player_list = []

        for item2 in cleaned_list:
            final_player_list.append(item2[0])


        al_gg_table_list.append(final_player_list)
        current_season = current_season - 1
    except:
        continue

for tr in al_gg_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    al_gg_table_header_list.append(ths)

al_gg_df = pd.DataFrame(al_gg_table_list, columns = al_gg_table_header_list)

al_gg_df
# Out:
#    Year & Common                P              C                     1B  \
# 0           2023     José Berríos     Jonah Heim         Nathaniel Lowe
# 1           2022     Shane Bieber   Jose Trevino  Vladimir Guerrero Jr.
# 2           2021   Dallas Keuchel    Sean Murphy           Yuli Gurriel
# 3           2020  Griffin Canning  Roberto Pérez             Evan White
# 4           2019       Mike Leake  Roberto Pérez             Matt Olson
# ..           ...              ...            ...                    ...
# 62          1961       Frank Lary    Earl Battey              Vic Power
# 63          1960     Bobby Shantz    Earl Battey              Vic Power
# 64          1959     Bobby Shantz   Sherm Lollar              Vic Power
# 65          1958     Bobby Shantz   Sherm Lollar              Vic Power
# 66          1957     Bobby Shantz   Sherm Lollar             Gil Hodges
#
#                   2B                  3B                SS                 OF  \
# 0     Andrés Giménez        Matt Chapman     Anthony Volpe      Adolis García
# 1     Andrés Giménez         Ramón Urías       Jeremy Peña        Steven Kwan
# 2      Marcus Semien        Matt Chapman     Carlos Correa  Andrew Benintendi
# 3    César Hernández  Isiah Kiner-Falefa     J.P. Crawford    Luis Robert Jr.
# 4     Yolmer Sanchez        Matt Chapman  Francisco Lindor    Kevin Kiermaier
# ..               ...                 ...               ...                ...
# 62  Bobby Richardson     Brooks Robinson     Luis Aparicio          Al Kaline
# 63        Nellie Fox     Brooks Robinson     Luis Aparicio         Jim Landis
# 64        Nellie Fox       Frank Malzone     Luis Aparicio          Al Kaline
# 65     Frank Bolling       Frank Malzone     Luis Aparicio          Al Kaline
# 66        Nellie Fox       Frank Malzone      Roy McMillan        Willie Mays
#
#                    OF               OF            Utility               Team
# 0         Steven Kwan  Kevin Kiermaier     Mauricio Dubón  Toronto Blue Jays
# 1         Myles Straw      Kyle Tucker        DJ LeMahieu   New York Yankees
# 2   Michael A. Taylor       Joey Gallo     Houston Astros               None
# 3          Joey Gallo      Alex Gordon  Cleveland Indians               None
# 4         Alex Gordon     Mookie Betts               None               None
# ..                ...              ...                ...                ...
# 62         Jim Landis     Jim Piersall               None               None
# 63      Minnie Miñoso      Roger Maris               None               None
# 64      Jackie Jensen    Minnie Miñoso               None               None
# 65       Jim Piersall     Norm Siebern               None               None
# 66          Al Kaline    Minnie Miñoso               None               None
#
# [67 rows x 12 columns]

# %%
nl_gg_df.insert(1,"League", "NL")
al_gg_df.insert(1,"League", "AL")
all_gold_gloves_df = al_gg_df.append(nl_gg_df)
all_gold_gloves_df
# Out:
#    Year & Common League                P              C  \
# 0           2023     AL     José Berríos     Jonah Heim
# 1           2022     AL     Shane Bieber   Jose Trevino
# 2           2021     AL   Dallas Keuchel    Sean Murphy
# 3           2020     AL  Griffin Canning  Roberto Pérez
# 4           2019     AL       Mike Leake  Roberto Pérez
# ..           ...    ...              ...            ...
# 62          1961     NL     Bobby Shantz  John Roseboro
# 63          1960     NL    Harvey Haddix   Del Crandall
# 64          1959     NL    Harvey Haddix   Del Crandall
# 65          1958     NL    Harvey Haddix   Del Crandall
# 66          1957     NL     Bobby Shantz   Sherm Lollar
#
#                        1B               2B                  3B  \
# 0          Nathaniel Lowe   Andrés Giménez        Matt Chapman
# 1   Vladimir Guerrero Jr.   Andrés Giménez         Ramón Urías
# 2            Yuli Gurriel    Marcus Semien        Matt Chapman
# 3              Evan White  César Hernández  Isiah Kiner-Falefa
# 4              Matt Olson   Yolmer Sanchez        Matt Chapman
# ..                    ...              ...                 ...
# 62             Bill White   Bill Mazeroski           Ken Boyer
# 63             Bill White   Bill Mazeroski           Ken Boyer
# 64             Gil Hodges     Charlie Neal           Ken Boyer
# 65             Gil Hodges   Bill Mazeroski           Ken Boyer
# 66             Gil Hodges       Nellie Fox       Frank Malzone
#
#                   SS                 OF                 OF               OF  \
# 0      Anthony Volpe      Adolis García        Steven Kwan  Kevin Kiermaier
# 1        Jeremy Peña        Steven Kwan        Myles Straw      Kyle Tucker
# 2      Carlos Correa  Andrew Benintendi  Michael A. Taylor       Joey Gallo
# 3      J.P. Crawford    Luis Robert Jr.         Joey Gallo      Alex Gordon
# 4   Francisco Lindor    Kevin Kiermaier        Alex Gordon     Mookie Betts
# ..               ...                ...                ...              ...
# 62       Maury Wills   Roberto Clemente        Willie Mays      Vada Pinson
# 63       Ernie Banks        Henry Aaron         Wally Moon      Willie Mays
# 64      Roy McMillan      Jackie Brandt        Henry Aaron      Willie Mays
# 65      Roy McMillan     Frank Robinson        Henry Aaron      Willie Mays
# 66      Roy McMillan        Willie Mays          Al Kaline    Minnie Miñoso
#
#               Utility               Team
# 0      Mauricio Dubón  Toronto Blue Jays
# 1         DJ LeMahieu   New York Yankees
# 2      Houston Astros               None
# 3   Cleveland Indians               None
# 4                None               None
# ..                ...                ...
# 62               None               None
# 63               None               None
# 64               None               None
# 65               None               None
# 66               None               None
#
# [134 rows x 13 columns]

# %%
roy_table_list = []
roy_table_header_list = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/roy.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
roy_table = soup.select_one('#div_roy')
        
# Grab data from table and put it into the list created above
for tr in roy_table.select('tr:has(td)'):
    tds = [td.get_text(strip=True) for td in tr.select('td')]
    roy_table_list.append(tds)

for tr in roy_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    roy_table_header_list.append(ths)
    
today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

roy_player_list = []
roy_year_list = []
league_list = []
counter = 1

while counter < len(roy_table_header_list):
    if roy_table_header_list[counter] != ['']:
        roy_year_list.append(roy_table_header_list[counter][0])
    counter = counter + 1
        

for item in roy_table_list:
    if item[0] != '':
        roy_player_list.append(item[1])
        league_list.append(item[0])
    else:
        current_season = current_season - 1

roy_year_list.pop(0)
        
roy_df = pd.DataFrame(
    {'Year': roy_year_list,
     'Player': roy_player_list,
     'League': league_list
    })

roy_df
# Out:
#      Year             Player League
# 0    2023   Gunnar Henderson     AL
# 1    2023     Corbin Carroll     NL
# 2    2022    Julio Rodríguez     AL
# 3    2022  Michael Harris II     NL
# 4    2021    Randy Arozarena     AL
# ..    ...                ...    ...
# 149  1950        Sam Jethroe     NL
# 150  1949        Roy Sievers     AL
# 151  1949       Don Newcombe     NL
# 152  1948            Al Dark     ML
# 153  1947    Jackie Robinson     ML
#
# [154 rows x 3 columns]

# %%
RLOY_table_list = []
RLOY_table_header_list = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/reliever.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
RLOY_table = soup.select_one('#div_reliever')
        
# Grab data from table and put it into the list created above
for tr in RLOY_table.select('tr:has(td)'):
    tds = [td.get_text(strip=True) for td in tr.select('td')]
    RLOY_table_list.append(tds)

for tr in RLOY_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    RLOY_table_header_list.append(ths)
    
today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

RLOY_player_list = []
RLOY_year_list = []
league_list = []
counter = 1

while counter < len(RLOY_table_header_list):
    if RLOY_table_header_list[counter] != ['']:
        RLOY_year_list.append(RLOY_table_header_list[counter][0])
    counter = counter + 1
        

for item in RLOY_table_list:
    if item[0] != '':
        RLOY_player_list.append(item[1])
        league_list.append(item[0])
    else:
        current_season = current_season - 1

# RLOY_year_list.pop(0)
        
RLOY_df = pd.DataFrame(
    {'Year': RLOY_year_list,
     'Player': RLOY_player_list,
     'League': league_list
    })

RLOY_df
# Out:
#     Year          Player League
# 0   2023  Félix Bautista     AL
# 1   2023  Devin Williams     NL
# 2   2022  Emmanuel Clase     AL
# 3   2022      Edwin Díaz     NL
# 4   2021   Liam Hendriks     AL
# ..   ...             ...    ...
# 90  1978  Rollie Fingers     NL
# 91  1977   Bill Campbell     AL
# 92  1977  Rollie Fingers     NL
# 93  1976   Bill Campbell     AL
# 94  1976  Rawly Eastwick     NL
#
# [95 rows x 3 columns]

# %%
ERA_champs_table_list = []
ERA_champs_table_header_list = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/pitching-era-titles.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
ERA_champs_table = soup.select_one('#div_titleist')
        
# Grab data from table and put it into the list created above
for tr in ERA_champs_table.select('tr:has(td)'):
    tds = [td.get_text(strip=True) for td in tr.select('td')]
    ERA_champs_table_list.append(tds)

for tr in ERA_champs_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    ERA_champs_table_header_list.append(ths)
    
today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

ERA_champs_player_list = []
ERA_champs_year_list = []
league_list = []
counter = 0
slash_list = []

while counter < len(ERA_champs_table_list[0]):
    if ERA_champs_table_list[0][counter] == '':
        ERA_champs_year_list.append(ERA_champs_table_list[0][counter - 4])
    else:
        ERA_champs_year_list.append(ERA_champs_table_list[0][counter])
        
    league_list.append(ERA_champs_table_list[0][counter + 1])
    ERA_champs_player_list.append(ERA_champs_table_list[0][counter + 2])
    slash_list.append(ERA_champs_table_list[0][counter + 3])

    counter = counter + 4
            
ERA_champs_df = pd.DataFrame(
    {'Year': ERA_champs_year_list,
     'Player': ERA_champs_player_list,
     'League': league_list,
     'Details': slash_list
    })

ERA_champs_df
# Out:
#      Year            Player League                       Details
# 0    2023       Gerrit Cole     AL        NYY 15-4, 2.63, 222 SO
# 1    2023       Blake Snell     NL        SDP 14-9, 2.25, 234 SO
# 2    2022  Justin Verlander     AL        HOU 18-4, 1.75, 185 SO
# 3    2022       Julio Urías     NL        LAD 17-7, 2.16, 166 SO
# 4    2021        Robbie Ray     AL        TOR 13-7, 2.84, 248 SO
# ..    ...               ...    ...                           ...
# 334  1875        Pud Galvin     NA    STL 4-2 (1 SV), 1.16, 8 SO
# 335  1874      Dick McBride     NA        ATH 33-22, 1.64, 37 SO
# 336  1873   Cherokee Fisher     NA   ATH 3-4 (2 SV), 1.81, 14 SO
# 337  1872   Cherokee Fisher     NA  BAL 10-1 (1 SV), 1.80, 20 SO
# 338  1871   George Zettlein     NA         CHI 18-9, 2.73, 22 SO
#
# [339 rows x 4 columns]

# %%
al_ss_table_list = []
al_ss_table_header_list = []

today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/silver_slugger_al.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
al_ss_table = soup.select_one('#div_award_grid')
        
# Grab data from table and put it into the list created above
for tr in al_ss_table.select('tr:has(td)'):
 
    try:
        temp_list = []

        for td in tr.find_all('td'):
            try:
                test3 = td.find('a').get('title') 
                temp_list.append(test3)
            except:
                continue

        cleaned_list = []

        for item in temp_list:
            temp_item = re.findall(r"^(.+?),", str(item))
            cleaned_list.append(temp_item)

        cleaned_list[0] = [current_season]
        final_player_list = []

        for item2 in cleaned_list:
            final_player_list.append(item2[0])


        al_ss_table_list.append(final_player_list)
        current_season = current_season - 1
    except:
        continue

for tr in al_ss_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    al_ss_table_header_list.append(ths)

al_ss_table_header_list[0].remove('Team')
    
al_ss_df = pd.DataFrame(al_ss_table_list, columns = al_ss_table_header_list)

al_ss_df
# Out:
#    Year & Common                 C                     1B               2B  \
# 0           2023   Adley Rutschman             Yandy Díaz    Marcus Semien
# 1           2022    Alejandro Kirk         Nathaniel Lowe      José Altuve
# 2           2021    Salvador Pérez  Vladimir Guerrero Jr.    Marcus Semien
# 3           2020    Salvador Pérez             José Abreu      DJ LeMahieu
# 4           2019      Mitch Garver         Carlos Santana      DJ LeMahieu
# 5           2018    Salvador Pérez             José Abreu      José Altuve
# 6           2017      Gary Sánchez            Eric Hosmer      José Altuve
# 7           2016    Salvador Pérez         Miguel Cabrera      José Altuve
# 8           2015      Brian McCann         Miguel Cabrera      José Altuve
# 9           2014         Yan Gomes             José Abreu      José Altuve
# 10          2013         Joe Mauer            Chris Davis    Robinson Canó
# 11          2012   A.J. Pierzynski         Prince Fielder    Robinson Canó
# 12          2011        Alex Avila        Adrián González    Robinson Canó
# 13          2010         Joe Mauer         Miguel Cabrera    Robinson Canó
# 14          2009         Joe Mauer          Mark Teixeira       Aaron Hill
# 15          2008         Joe Mauer         Justin Morneau   Dustin Pedroia
# 16          2007      Jorge Posada            Carlos Peña  Plácido Polanco
# 17          2006         Joe Mauer         Justin Morneau    Robinson Canó
# 18          2005     Jason Varitek          Mark Teixeira  Alfonso Soriano
# 19          2004   Víctor Martínez          Mark Teixeira  Alfonso Soriano
# 20          2003      Jorge Posada         Carlos Delgado       Bret Boone
# 21          2002      Jorge Posada           Jason Giambi  Alfonso Soriano
# 25      Albert Belle       José Canseco              None
# 26     David Justice     Edgar Martínez              None
# 27      Albert Belle       Paul Molitor              None
# 28      Albert Belle     Edgar Martínez              None
# 29      Albert Belle       Julio Franco              None
# 30      Albert Belle       Paul Molitor              None
# 31     Juan González      Dave Winfield              None
# 32      José Canseco       Frank Thomas              None
# 33  Rickey Henderson        Dave Parker              None
# 34      Rubén Sierra      Harold Baines              None
# 35    Mike Greenwell       Paul Molitor              None
# 36      Dwight Evans       Paul Molitor              None
# 37    Jesse Barfield         Don Baylor              None
# 38  Rickey Henderson         Don Baylor              None
# 39        Tony Armas     Andre Thornton              None
# 40      Lloyd Moseby         Don Baylor              None
# 41    Reggie Jackson          Hal McRae              None
# 42      Dwight Evans          Al Oliver              None
# 43     Willie Wilson     Reggie Jackson              None

# %%
nl_ss_table_list = []
nl_ss_table_header_list = []

today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/silver_slugger_nl.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
nl_ss_table = soup.select_one('#div_award_grid')
        
# Grab data from table and put it into the list created above
for tr in nl_ss_table.select('tr:has(td)'):
 
    try:
        temp_list = []

        for td in tr.find_all('td'):
            try:
                test3 = td.find('a').get('title') 
                temp_list.append(test3)
            except:
                continue

        cleaned_list = []

        for item in temp_list:
            temp_item = re.findall(r"^(.+?),", str(item))
            cleaned_list.append(temp_item)

        cleaned_list[0] = [current_season]
        final_player_list = []

        for item2 in cleaned_list:
            final_player_list.append(item2[0])


        nl_ss_table_list.append(final_player_list)
        current_season = current_season - 1
    except:
        continue

for tr in nl_ss_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    nl_ss_table_header_list.append(ths)

nl_ss_table_header_list[0].remove('Team')
nl_ss_table_list[0].insert(1, "None")
    
nl_ss_df = pd.DataFrame(nl_ss_table_list, columns = nl_ss_table_header_list)

nl_ss_df
# Out:
#    Year & Common                    P                  C                1B  \
# 0           2023                 None  William Contreras        Matt Olson
# 1           2022        J.T. Realmuto   Paul Goldschmidt       Jeff McNeil
# 2           2021            Max Fried       Buster Posey   Freddie Freeman
# 3           2020        Marcell Ozuna    Travis d'Arnaud   Freddie Freeman
# 4           2019         Zack Greinke      J.T. Realmuto   Freddie Freeman
# 5           2018       Germán Márquez      J.T. Realmuto  Paul Goldschmidt
# 6           2017      Adam Wainwright       Buster Posey  Paul Goldschmidt
# 7           2016         Jake Arrieta       Wilson Ramos     Anthony Rizzo
# 8           2015    Madison Bumgarner       Buster Posey  Paul Goldschmidt
# 9           2014    Madison Bumgarner       Buster Posey   Adrián González
# 10          2013         Zack Greinke      Yadier Molina  Paul Goldschmidt
# 11          2012    Stephen Strasburg       Buster Posey      Adam LaRoche
# 12          2011        Daniel Hudson       Brian McCann    Prince Fielder
# 13          2010      Yovani Gallardo       Brian McCann     Albert Pujols
# 14          2009      Carlos Zambrano       Brian McCann     Albert Pujols
# 15          2008      Carlos Zambrano       Brian McCann     Albert Pujols
# 16          2007         Micah Owings     Russell Martin    Prince Fielder
# 17          2006      Carlos Zambrano       Brian McCann       Ryan Howard
# 18          2005        Jason Marquis    Michael Barrett        Derrek Lee
# 20        Barry Bonds    Gary Sheffield           None            None
# 21         Sammy Sosa       Barry Bonds           None            None
# 22         Sammy Sosa       Barry Bonds           None            None
# 23         Sammy Sosa       Barry Bonds           None            None
# 24  Vladimir Guerrero        Sammy Sosa           None            None
# 25         Sammy Sosa       Moisés Alou           None            None
# 26         Tony Gwynn       Barry Bonds           None            None
# 27     Gary Sheffield       Barry Bonds           None            None
# 28         Sammy Sosa    Dante Bichette           None            None
# 29        Moisés Alou       Barry Bonds           None            None
# 30      Lenny Dykstra       Barry Bonds           None            None
# 31       Larry Walker       Barry Bonds           None            None
# 32           Ron Gant       Barry Bonds           None            None
# 33      Bobby Bonilla       Barry Bonds           None            None
# 34         Tony Gwynn        Eric Davis           None            None
# 35        Kirk Gibson    Andy Van Slyke           None            None
# 36       Andre Dawson        Eric Davis           None            None
# 37         Tim Raines       Dave Parker           None            None
# 38        Dave Parker       Dale Murphy           None            None
# 39        Dale Murphy         José Cruz           None            None
# 40          José Cruz      Andre Dawson           None            None
# 41        Dale Murphy       Leon Durham           None            None
# 42      George Foster      Andre Dawson           None            None
# 43        Dusty Baker      Andre Dawson           None            None

# %%
# al_ss_df = al_ss_df.reset_index()
al_ss_df.insert(1,"P", " ")
nl_ss_df.insert(1,"League", "NL")
al_ss_df.insert(1,"League", "AL")

# %%
all_silver_sluggers_df = al_ss_df.append(nl_ss_df)
all_silver_sluggers_df
# al_ss_df
# Out:
#    Year & Common League                    P                C  \
# 0           2023     AL                       Adley Rutschman
# 1           2022     AL                        Alejandro Kirk
# 2           2021     AL                        Salvador Pérez
# 3           2020     AL                        Salvador Pérez
# 4           2019     AL                          Mitch Garver
# ..           ...    ...                  ...              ...
# 39          1984     NL          Rick Rhoden      Gary Carter
# 40          1983     NL  Fernando Valenzuela    Terry Kennedy
# 41          1982     NL         Don Robinson      Gary Carter
# 42          1981     NL  Fernando Valenzuela      Gary Carter
# 43          1980     NL           Bob Forsch      Ted Simmons
#
#                        1B             2B             3B               SS  \
# 0              Yandy Díaz  Marcus Semien  Rafael Devers     Corey Seager
# 1          Nathaniel Lowe    José Altuve   José Ramírez  Xander Bogaerts
# 2   Vladimir Guerrero Jr.  Marcus Semien  Rafael Devers  Xander Bogaerts
# 3              José Abreu    DJ LeMahieu   José Ramírez     Tim Anderson
# 4          Carlos Santana    DJ LeMahieu   Alex Bregman  Xander Bogaerts
# ..                    ...            ...            ...              ...
# 39        Keith Hernandez  Ryne Sandberg   Mike Schmidt  Garry Templeton
# 40        George Hendrick     Johnny Ray   Mike Schmidt      Dickie Thon
# 41              Al Oliver     Joe Morgan   Mike Schmidt  Dave Concepción
# 42              Pete Rose   Manny Trillo   Mike Schmidt  Dave Concepción
# 43        Keith Hernandez   Manny Trillo   Mike Schmidt  Garry Templeton
#
#                  OF                 OF            OF              DH  \
# 0   Julio Rodríguez    Luis Robert Jr.   Kyle Tucker   Shohei Ohtani
# 1        Mike Trout    Julio Rodríguez   Aaron Judge  Yordan Álvarez
# 2    Cedric Mullins  Teoscar Hernández   Aaron Judge   Shohei Ohtani
# 3        Mike Trout  Teoscar Hernández  Eloy Jiménez     Nelson Cruz
# 4   George Springer         Mike Trout  Mookie Betts     Nelson Cruz
# ..              ...                ...           ...             ...
# 39       Tony Gwynn        Dale Murphy     José Cruz            None
# 40      Dale Murphy          José Cruz  Andre Dawson            None
# 41   Pedro Guerrero        Dale Murphy   Leon Durham            None
# 42      Dusty Baker      George Foster  Andre Dawson            None
# 43  George Hendrick        Dusty Baker  Andre Dawson            None
#
#              Utility
# 0   Gunnar Henderson
# 1        Luis Arráez
# 2               None
# 3               None
# 4               None
# ..               ...
# 39              None
# 40              None
# 41              None
# 42              None
# 43              None
#
# [88 rows x 13 columns]

# %%
all_MLB_table_list = []
all_MLB_table_header_list = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/all_mlb.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
all_MLB_table = soup.select_one('#div_all_mlb')
        
# Grab data from table and put it into the list created above
for tr in all_MLB_table.select('tr:has(td)'):
    tds = [td.get_text(strip=True) for td in tr.select('td')]
    all_MLB_table_list.append(tds)

for tr in all_MLB_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    all_MLB_table_header_list.append(ths)

year_list = []
i = 1
while i < (len(all_MLB_table_header_list)):
    year_list.append(all_MLB_table_header_list[i][0])
    i = i + 1

for j in range(len(all_MLB_table_list)):
    all_MLB_table_list[j].insert(0, year_list[j])
    j = j + 1
    

all_MLB_df = pd.DataFrame(all_MLB_table_list, columns = all_MLB_table_header_list[0])
all_MLB_df
# Out:
#    Year Team         SP       SP        SP         SP         SP        RP  \
# 0  2023  1st
# 1  2023  2nd
# 2  2022  1st  Alcántara   Manoah    Ohtani     Valdez  Verlander     Clase
# 3  2022  2nd      Cease    Fried      Nola   Scherzer      Urías   Helsley
# 4  2021  1st    Buehler   Burnes      Cole        Ray   Scherzer     Hader
# 5  2021  2nd      Fried  Gausman    Ohtani      Urías    Wheeler  Iglesias
# 6  2020  1st      Bauer   Bieber   Darvish     deGrom      Fried  Anderson
# 7  2020  2nd       Cole  Kershaw     Lamet      Maeda        Ryu      Hand
# 8  2019  1st       Cole   deGrom  Scherzer  Strasburg  Verlander     Hader
# 9  2019  2nd   Flaherty  Greinke    Morton        Ryu     Soroka   Chapman
#
#          RP         C           1B        2B       3B        SS           OF  \
# 0
# 1
# 2      Díaz  Realmuto  Goldschmidt    Altuve  Machado    Turner        Betts
# 3   Pressly     Smith      Freeman   Giménez  Arenado    Lindor    Rodríguez
# 4  Hendriks     Pérez     Guerrero    Semien    Riley     Tatís       Harper
# 5    Jansen     Posey      Freeman    Albies   Devers    Turner  Castellanos
# 6  Hendriks     Pérez      Freeman  LeMahieu  Machado     Tatís        Betts
# 7  Williams  Realmuto        Abreu      Lowe  Ramírez    Seager        Acuña
# 8     Yates  Realmuto       Alonso  LeMahieu   Rendon  Bogaerts    Bellinger
# 9  Hendriks   Grandal      Freeman    Altuve  Bregman    Semien        Acuña
#
#           OF           OF       DH
# 0
# 1
# 2      Judge        Trout  Álvarez
# 3  Schwarber       Tucker   Ohtani
# 4      Judge         Soto   Ohtani
# 5  Hernández       Tucker  Álvarez
# 6       Soto        Trout    Ozuna
# 7   Conforto  Yastrzemski     Cruz
# 8      Trout       Yelich     Cruz
# 9      Betts         Soto  Álvarez

# %%
    
clemente_award_table_list = []
clemente_award_table_header_list = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.baseball-reference.com/awards/clemente.shtml'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
clemente_award_table = soup.select_one('#div_clemente')
        
# Grab data from table and put it into the list created above
for tr in clemente_award_table.select('tr:has(td)'):
    tds = [td.get_text(strip=True) for td in tr.select('td')]
    clemente_award_table_list.append(tds)

for tr in clemente_award_table.select('tr:has(th)'):
    ths = [th.get_text(strip=True) for th in tr.select('th')]
    clemente_award_table_header_list.append(ths)
    
today = date.today()

# dd/mm/YY
if int(today.strftime("%M")) > 11:
    current_season = int(today.strftime("%Y"))
else:
    current_season = (int(today.strftime("%Y")) - 1)

clemente_award_player_list = []
clemente_award_year_list = []
league_list = []
counter = 0
slash_list = []

     
clemente_award_table_header_list[1].pop(0)
clemente_award_df = pd.DataFrame(clemente_award_table_list, columns = clemente_award_table_header_list[1])


year_list = []
i = 2
while i < (len(clemente_award_table_header_list)):
    if clemente_award_table_header_list[i][0] == '':
        i = i + 1
    else:
        year_list.append(clemente_award_table_header_list[i][0])
        i = i + 1

clemente_award_df = clemente_award_df[clemente_award_df.Name != '']
clemente_award_df.insert(0, "Year", year_list)


clemente_award_df
# Out:
#      Year  Lg               Name       Tm   WAR    BA   OBP   SLG  HR  RBI  \
# 0    2023  ML        Aaron Judge      NYY   4.5  .267  .406  .613  37   75
# 2    2022  ML      Justin Turner      LAD   2.0  .278  .350  .438  13   81
# 4    2021  ML        Nelson Cruz  MIN,TBR   2.5  .265  .334  .497  32   86
# 6    2020  ML    Adam Wainwright      STL   0.5
# 8    2019  ML    Carlos Carrasco      CLE   0.1
# 10   2018  ML      Yadier Molina      STL   1.5  .261  .314  .436  20   74
# 12   2017  ML      Anthony Rizzo      CHC   4.5  .273  .392  .507  32  109
# 14   2016  ML  Curtis Granderson      NYM   2.8  .237  .335  .464  30   59
# 16   2015  ML   Andrew McCutchen      PIT   5.0  .292  .401  .488  23   96
# 18   2014  ML       Paul Konerko      CHW  -0.7  .207  .254  .317   5   22
# 19   2014  ML      Jimmy Rollins      PHI   4.1  .243  .323  .394  17   55
# 21   2013  ML     Carlos Beltrán      STL   2.3  .296  .339  .491  24   84
# 23   2012  ML    Clayton Kershaw      LAD   6.8  .207  .230  .224   0    2
# 25   2011  ML        David Ortiz      BOS   4.0  .309  .398  .554  29   96
# 27   2010  ML      Tim Wakefield      BOS  -0.7  .000  .200  .000   0    0
# 29   2009  ML        Derek Jeter      NYY   6.6  .334  .406  .465  18   66
# 31   2008  ML      Albert Pujols      STL   9.2  .357  .462  .653  37  116
# 33   2007  ML       Craig Biggio      HOU  -2.1  .251  .285  .381  10   50
# 35   2006  ML     Carlos Delgado      NYM   2.7  .265  .361  .548  38  114
# 37   2005  ML        John Smoltz      ATL   4.9  .147  .183  .206   0    3
# 39   2004  ML     Edgar Martínez      SEA  -0.3  .263  .342  .385  12   63
# 41   2003  ML        Jamie Moyer      SEA   4.8  .400  .400  .400   0    0
# 43   2002  ML          Jim Thome      CLE   7.4  .304  .445  .677  52  118
# 45   2001  ML     Curt Schilling      ARI   8.5  .133  .143  .145   0    1
# 47   2000  ML          Al Leiter      NYM   4.3  .052  .113  .052   0    0
# 49   1999  ML         Tony Gwynn      SDP   1.8  .338  .381  .477  10   62
# 51   1998  ML         Sammy Sosa      CHC   6.5  .308  .377  .647  66  158
# 53   1997  ML         Eric Davis      BAL   1.1  .304  .358  .525   8   25
# 55   1996  ML      Kirby Puckett
# 57   1995  ML        Ozzie Smith      STL  -0.7  .199  .282  .244   0   11
# 59   1994  ML      Dave Winfield      MIN   0.1  .252  .321  .425  10   43
# 61   1993  ML       Barry Larkin      CIN   3.8  .315  .394  .445   8   51
# 63   1992  ML     Cal Ripken Jr.      BAL   4.1  .251  .323  .366  14   72
# 65   1991  ML    Harold Reynolds      SEA   2.7  .254  .332  .341   3   57
# 67   1990  ML       Dave Stewart      OAK   5.2
# 69   1989  ML        Gary Carter      NYM  -0.3  .183  .241  .275   2   15
# 71   1988  ML        Dale Murphy      ATL   3.1  .226  .313  .421  24   77
# 73   1987  ML     Rick Sutcliffe      CHC   6.5  .148  .213  .235   0    6
# 75   1986  ML       Garry Maddox      PHI  -0.1  .429  .556  .429   0    1
# 77   1985  ML         Don Baylor      NYY   0.7  .231  .330  .430  23   91
# 79   1984  ML         Ron Guidry      NYY   1.5
# 81   1983  ML       Cecil Cooper      MIL   4.0  .307  .341  .508  30  126
# 83   1982  ML      Ken Singleton      BAL   0.7  .251  .349  .381  14   77
# 85   1981  ML       Steve Garvey      LAD   2.0  .283  .322  .411  10   64
# 87   1980  ML        Phil Niekro      ATL   2.9  .133  .143  .189   0    5
# 89   1979  ML     Andre Thornton      CLE   2.7  .233  .347  .449  26   93
# 91   1978  ML      Greg Luzinski      PHI   5.2  .265  .388  .526  35  101
# 93   1977  ML          Rod Carew      MIN   9.7  .388  .449  .570  14  100
# 95   1976  ML          Pete Rose      CIN   7.0  .323  .404  .450  10   63
# 97   1975  ML          Lou Brock      STL   1.8  .309  .359  .400   3   47
# 99   1974  ML    Willie Stargell      PIT   5.4  .301  .407  .537  25   96
# 101  1973  ML          Al Kaline      DET   0.5  .255  .320  .394  10   45
# 103  1972  ML    Brooks Robinson      BAL   3.5  .250  .303  .342   8   64
# 105  1971  ML        Willie Mays      SFG   6.3  .271  .425  .482  18   61
#
#      SB   W   L SV   ERA     IP   SO
# 0     3
# 2     3
# 4     3
# 6         5   3  0  3.15   65.2   54
# 8         6   7  1  5.29   80.0   96
# 10    4
# 12   10
# 14    4
# 16   11
# 18    0
# 19   28
# 21    2
# 23    0  14   9  0  2.53  227.2  229
# 25    1
# 27    0   4  10  0  5.34  140.0   84
# 29   30
# 31    7
# 33    4
# 35    0
# 37    0  14   7  0  3.06  229.2  169
# 39    1
# 41    0  21   7  0  3.27  215.0  129
# 43    1
# 45    0  22   6  0  2.98  256.2  293
# 47    0  16   8  0  3.20  208.0  200
# 49    7
# 51   18
# 53    6
# 55
# 57    4
# 59    2
# 61   14
# 63    4
# 65   28
# 67       22  11  0  2.56  267.0  166
# 69    0
# 71    3
# 73    1  18  10  0  3.68  237.1  174
# 75    0
# 77    0
# 79       10  11  0  4.51  195.2  127
# 81    2
# 83    0
# 85    3
# 87    0  15  18  1  3.63  275.0  176
# 89    5
# 91    8
# 93   23
# 95    9
# 97   56
# 99    0
# 101   4
# 103   1
# 105  23

# %%
allstar_table_list = []
year_list = []

today = date.today()

# dd/mm/YY
allstar_year = int(today.strftime("%Y"))
if int(today.strftime("%m")) < 8:
    allstar_year = allstar_year - 1

start_year = 1933

while start_year <= allstar_year:   
    
    if counter > 2:
        counter = 1
#         print("Counter Reverted")
#     else:
#         print(f"It worked: {counter} - {start_year}")
        
    if start_year == 1959 or start_year == 1960 or start_year == 1961 or start_year == 1962:
        url = f'https://www.baseball-reference.com/allstar/{start_year}-allstar-game-{counter}.shtml'
        counter = counter + 1
        
        if counter > 2:
            two_allstar_year = "No"
        else:
            two_allstar_year = "Yes"
    else:
        url = f'https://www.baseball-reference.com/allstar/{start_year}-allstar-game.shtml'
        counter = 1
        two_allstar_year = "No"
    
    soup = BeautifulSoup(requests.get(url).content, 'html.parser')

    # Grab the table element that has MLB player statistics
    allstar_table = soup.select_one('#all_lineups')

    comment = allstar_table.find(text=lambda text: isinstance(text, Comment))
    if comment.find("table") > 0:
            comment_soup = BeautifulSoup(comment, 'html.parser')
            table = comment_soup.find_all("table")

    # Grab data from table and put it into the list created above
    for tr in table[0].select('tr:has(td)'):
        tds = [td.get_text(strip=True) for td in tr.select('td')]
        allstar_table_list.append(tds)
        year_list.append(f'{start_year}: Game {counter}')

        
    for tr in table[1].select('tr:has(td)'):
        tds = [td.get_text(strip=True) for td in tr.select('td')]
        allstar_table_list.append(tds)        
        year_list.append(f'{start_year}: Game {counter}')
        
#     allstar_table_list.append(start_year)

    
    
    if start_year == 1944 or start_year == 2019:
        start_year = start_year + 2
    elif two_allstar_year == "Yes":
        continue
    else:
        start_year = start_year + 1
    
    time.sleep(3)


allstar_df = pd.DataFrame(allstar_table_list, columns = ('Lineup Spot','Player','Position')) 
allstar_df['Year'] = year_list

allstar_df
# Out:
#      Lineup Spot            Player Position          Year
# 0              1     Pepper Martin       3B  1933: Game 1
# 1              2    Frankie Frisch       2B  1933: Game 1
# 2              3       Chuck Klein       RF  1933: Game 1
# 3              4       Chick Hafey       LF  1933: Game 1
# 4              5        Bill Terry       1B  1933: Game 1
# ...          ...               ...      ...           ...
# 6112                   Pablo López        P  2023: Game 1
# 6113              Michael Lorenzen        P  2023: Game 1
# 6114              Shane McClanahan        P  2023: Game 1
# 6115                 Jordan Romano        P  2023: Game 1
# 6116                Framber Valdez        P  2023: Game 1
#
# [6117 rows x 4 columns]

# %%
hof_df.to_csv('MLB_hof.csv')
mvp_df.to_csv('MLB_mvp.csv')
cya_df.to_csv('MLB_cya.csv')
clemente_award_df.to_csv('clemente_award.csv')
all_MLB_df.to_csv('all_MLB_df.csv')
all_silver_sluggers_df.to_csv('MLB_silver_sluggers.csv')
ERA_champs_df.to_csv('MLB_ERA_champs.csv')
RLOY_df.to_csv('MLB_RLOY.csv')
roy_df.to_csv('MLB_ROY.csv')
all_gold_gloves_df.to_csv('MLB_gold_gloves.csv')
batting_champs_df.to_csv('MLB_batting_champs.csv')
allstar_df.to_csv('MLB_allstars.csv')
