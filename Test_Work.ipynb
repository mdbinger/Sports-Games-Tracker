# %%
# Import needed dependencies
import requests
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from datetime import date
from bs4 import BeautifulSoup, Comment

box_score = []

# input URL and use BeautifulSoup to parse through the page
url = f'https://www.basketball-reference.com/boxscores/202212190SAC.html'
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

# Grab the table element that has NBA player statistics
box_score_table = soup.select_one('#all_line_score')

for comment in box_score_table.find_all(text=lambda text: isinstance(text, Comment)):
    if comment.find("<table ") > 0:
        comment_soup = BeautifulSoup(comment, 'html.parser')
        table = comment_soup.find("table")
        
# Grab data from table and put it into the list created above
for tr in table.select('tr:has(td)'):
    tds3 = [td.get_text(strip=True) for td in tr.select('td')]
    box_score.append(tds3)

# %%
abc = soup.find_all(name="strong")

# %%
abc[8].string
# Out:
# 'Time of Game:\xa0'

# %%
for text in abc:
    print(text.get_text())
# Out:
# Charlotte Hornets at Sacramento Kings Box Score, December 19, 2022
#
# Charlotte Hornets
#
#
# Sacramento Kings
#
# Inactive:
# CHO
# SAC
# Officials:
# Attendance:
# Time of Game:
# Charlotte Hornets at Sacramento Kings Box Score, December 19, 2022
# In the News
# All-Time Greats
# Active Greats
# Atlantic
# Central
# Southeast
# Northwest
# Pacific
# Southwest
# Player Finders
# Team Finders
# Other Finders
# Site Last Updated:

# %%
import re
from urllib.request import urlopen

url = "https://www.basketball-reference.com/boxscores/202212190SAC.html"
page = urlopen(url)
html = page.read().decode("utf-8")

pattern = "<strong.*?>Attendance: </strong.*?>"
match_results = re.search(pattern, html, re.IGNORECASE)
title = match_results.group()
title = re.sub("<.*?>", "", title) # Remove HTML tags

print(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2d/w0_y9zt547v2y0371_wclbcm0000gn/T/ipykernel_2572/3819819857.py in <module>
#       8 pattern = "<strong.*?>Attendance: </strong.*?>"
#       9 match_results = re.search(pattern, html, re.IGNORECASE)
# ---> 10 title = match_results.group()
#      11 title = re.sub("<.*?>", "", title) # Remove HTML tags
#      12
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
soup.strong.string
# Out:
# 'Charlotte Hornets at Sacramento Kings Box Score, December 19, 2022'

# %%
text = soup.get_text()

# %%
text.find("Attendance")
# Out:
# 15061

# %%
print(text)
# Out:
# Hornets vs Kings, December 19, 2022 | Basketball-Reference.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Sports Reference ®
# Baseball
# Football (college)
# Basketball (college)
# Hockey
# Fußball
# Blog
# Stathead ®
# Questions or Comments?
# Welcome  · Your Account
# Logout
# Login
# Create Account
#
#
# MENU
#
# Players
# Teams
# Seasons
# Leaders
# Scores
# WNBA
# Draft
# Stathead
# Newsletter
# Full Site Menu Below
#
# You are here: BBR Home Page  > Box Scores  > Charlotte Hornets at Sacramento Kings Box Score, December 19, 2022
# Welcome  · Your Account
# Logout
# Login
# Create Account
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Dec 19, 2022 NBA Scores & Boxes
# 2022-23 NBA Schedule & Results
# Charlotte Hornets Schedule
# Sacramento Kings Schedule
# Team and League Schedules
#
#
# Charlotte Hornets Schedule
# Sacramento Kings Schedule
# 2022-23 NBA Schedule & Results
#
#
#
#
#
# Charlotte Hornets at Sacramento Kings Box Score, December 19, 2022
#
#
#
#
#
#
#
#
#
#
#
# via Sports Logos.net
# About logos
#
#
# Charlotte Hornets
#
#
#
# 125
# 8-23
#
# Prev Game
# Next Game
#
#
#
#
#
#
# via Sports Logos.net
# About logos
#
#
# Sacramento Kings
#
#
#
# 119
# 16-13
#
# Prev Game
# Next Game
#
#
#
# 10:00 PM, December 19, 2022Golden 1 Center, Sacramento, California
# Logos via Sports Logos.net
#             / About logos
#
#
#
#
#
#
#
#
#
#
#
#
#
# Box Score
#
# Play-By-Play
#
# Shot Charts
#
# Plus/Minus
#
#
#
#
#
# Line Score
#
#
#
#
#
#
#
#
#
# Four Factors
#
#
#
#
#
#
#
#
# Game Q1 Q2 H1 Q3 Q4 H2
#
#
# Charlotte Hornets Basic and Advanced Stats
#
#
#
#
#
#
# Charlotte Hornets Basic and Advanced Stats Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Kelly Oubre Jr.38:271225.48038.37546.6671891114231+1
# Gordon Hayward36:43812.66712.500221.0001451104219+18
# P.J. Washington29:0316.16714.25000189201053-5
# LaMelo Ball27:28919.474510.5000014512002623+3
# Mason Plumlee25:0878.8750012.5000443031315-4
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Théo Maledon26:04410.40003.00046.6670773100212+6
# Jalen McDaniels25:5015.20004.000441.000123202226+3
# Nick Richards22:5269.6670023.66756112101314+10
# JT Thor8:24111.0000000123000002-2
# James BouknightDid Not Play
# Kai JonesDid Not Play
# Team Totals2404995.5161031.3231723.73911455626471425125
#
#
#
#
#
#
#
#
#
# Charlotte Hornets (Q1)
#
#
#
#
#
#
# Charlotte Hornets (Q1) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Kelly Oubre Jr.9:5349.44413.33300033010119+2
# Gordon Hayward8:25331.0000000022000006+7
# P.J. Washington9:5314.25012.50000123001003+2
# LaMelo Ball6:3012.500111.000000006000230
# Mason Plumlee4:26111.0000000000001022-7
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Théo Maledon5:3001.0000012.500011100011+9
# Jalen McDaniels5:42111.00000221.000000000004+9
# Nick Richards7:3458.62500111.0004370001211+16
# JT Thor2:07000000011000000+7
# James BouknightDid Not Play
# Kai JonesDid Not Play
# Team Totals601629.55236.50045.800512177122839
#
#
#
#
#
#
#
#
#
# Charlotte Hornets (Q2)
#
#
#
#
#
#
# Charlotte Hornets (Q2) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Kelly Oubre Jr.8:4547.57101.00002.0000001000080
# Gordon Hayward9:5624.50000221.0001230101060
# P.J. Washington4:1901.00001.00000000100020-10
# LaMelo Ball1:2202.00001.00000000100010-1
# Mason Plumlee6:09221.0000000000200004+2
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Théo Maledon12:0037.42902.00000044000016-6
# Jalen McDaniels7:1201.00001.00000011100110-3
# Nick Richards5:51000012.500000110001-8
# JT Thor4:26111.0000000101000002-4
# James BouknightDid Not Play
# Kai JonesDid Not Play
# Team Totals601225.48006.00036.5002797202527
#
#
#
#
#
#
#
#
#
# Charlotte Hornets (H1)
#
#
#
#
#
#
# Charlotte Hornets (H1) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Kelly Oubre Jr.18:38816.50014.25002.0000331101117+2
# Gordon Hayward18:2157.71400221.0001450101012+7
# P.J. Washington14:1215.20013.33300123101023-8
# LaMelo Ball7:5214.25012.50000000700033-1
# Mason Plumlee10:35331.0000000000201026-5
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Théo Maledon17:3038.37502.00012.500055100027+3
# Jalen McDaniels12:5412.50001.000221.000011100114+6
# Nick Richards13:2558.6250023.6674371101212+8
# JT Thor6:33111.0000000112000002+3
# James BouknightDid Not Play
# Kai JonesDid Not Play
# Team Totals1202854.519312.250711.63671926143241366
#
#
#
#
#
#
#
#
#
# Charlotte Hornets (Q3)
#
#
#
#
#
#
# Charlotte Hornets (Q3) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Kelly Oubre Jr.12:0026.33313.333221.000033001307-4
# Gordon Hayward8:4912.50012.50000000000013+3
# P.J. Washington7:400000000441000200
# LaMelo Ball8:1225.40002.00000112300104-2
# Mason Plumlee8:12331.0000012.500011102107-2
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Théo Maledon3:48000000000100000-2
# Jalen McDaniels5:4002.00002.000221.000011000002-6
# Nick Richards3:48111.0000000011000002-2
# JT Thor1:51000000011000000-5
# James BouknightDid Not Play
# Kai JonesDid Not Play
# Team Totals60919.47429.22256.833112136035325
#
#
#
#
#
#
#
#
#
# Charlotte Hornets (Q4)
#
#
#
#
#
#
# Charlotte Hornets (Q4) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Kelly Oubre Jr.7:4923.667111.000221.000123000017+3
# Gordon Hayward9:3323.6670000000100314+8
# P.J. Washington7:1101.00001.00000022000010+3
# LaMelo Ball11:25610.60046.667000332001316+6
# Mason Plumlee6:2112.5000000033000012+3
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Théo Maledon4:4612.50001.00034.750022110005+5
# Jalen McDaniels7:1601.00001.00000101102110+3
# Nick Richards5:39000000123100010+4
# JT Thor
# James BouknightDid Not Play
# Kai JonesDid Not Play
# Team Totals601222.545510.50056.833314176125934
#
#
#
#
#
#
#
#
#
# Charlotte Hornets (H2)
#
#
#
#
#
#
# Charlotte Hornets (H2) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Kelly Oubre Jr.19:4949.44424.500441.0001560013114-1
# Gordon Hayward18:2235.60012.50000000100327+11
# P.J. Washington14:5101.00001.00000066100030+3
# LaMelo Ball19:37815.53348.500001455002320+4
# Mason Plumlee14:3345.8000012.500044102119+1
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Théo Maledon8:3412.50001.00034.750022210005+3
# Jalen McDaniels12:5603.00003.000221.000112102112-3
# Nick Richards9:27111.0000000134100012+2
# JT Thor1:51000000011000000-5
# James BouknightDid Not Play
# Kai JonesDid Not Play
# Team Totals1202141.512719.3681012.833426301215101259
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Table
#
#
#
# Advanced Box Score Stats
#
#
# Starters
# MP
# TS%
# eFG%
# 3PAr
# FTr
# ORB%
# DRB%
# TRB%
# AST%
# STL%
# BLK%
# TOV%
# USG%
# ORtg
# DRtg
# BPM
#
#
# Kelly Oubre Jr.38:27.561.540.320.2402.918.211.53.71.22.012.633.2102112-1.9
# Gordon Hayward36:43.738.708.167.1673.09.56.73.41.20.023.718.5111115-2.1
# P.J. Washington29:03.250.250.667.0003.824.015.27.00.02.70.08.385111-6.5
# LaMelo Ball27:28.605.605.526.0004.112.78.963.00.00.09.530.813311510.5
# Mason Plumlee25:08.845.875.000.2500.013.97.816.10.09.210.115.81531099.3
#
# Reserves
# MP
# TS%
# eFG%
# 3PAr
# FTr
# ORB%
# DRB%
# TRB%
# AST%
# STL%
# BLK%
# TOV%
# USG%
# ORtg
# DRtg
# BPM
#
# Théo Maledon26:04.475.400.300.6000.023.413.213.31.70.00.019.5114111-2.1
# Jalen McDaniels25:50.444.200.800.8004.36.85.77.90.06.022.813.791113-5.1
# Nick Richards22:52.678.667.000.33324.422.923.611.52.00.08.819.91431105.5
# JT Thor8:241.0001.000.000.00013.320.817.50.00.00.00.04.82061162.7
# James BouknightDid Not Play
# Kai JonesDid Not Play
# Team Totals240.595.568.326.24225.681.857.153.13.811.311.8100.0118.3112.6
#
#
#
#
#
#
#
#
#
# Sacramento Kings Basic and Advanced Stats
#
#
#
#
#
#
# Sacramento Kings Basic and Advanced Stats Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Domantas Sabonis40:441219.632221.00025.400518237101428+6
# De'Aaron Fox33:431425.56025.40079.7781452002537-20
# Kevin Huerter31:47311.27338.37502.000123100059+6
# Keegan Murray31:0249.44435.60002.0000110110411+8
# Harrison Barnes29:2937.42902.00058.6250333201111+2
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Malik Monk24:51413.30816.16734.7500114002112-4
# Davion Mitchell21:0434.75012.50000101510007+1
# Terence Davis14:4314.25003.00001.000000130012-11
# Neemias Queta7:1613.3330000224001102-12
# Trey Lyles5:20000000011000120-6
# Matthew DellavedovaDid Not Play
# Chimezie MetuDid Not Play
# Richaun HolmesDid Not Play
# KZ OkpalaDid Not Play
# Alex LenDid Not Play
# Team Totals2404595.4741233.3641731.5481032422382823119
#
#
#
#
#
#
#
#
#
# Sacramento Kings (Q1)
#
#
#
#
#
#
# Sacramento Kings (Q1) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Domantas Sabonis9:5335.6000013.333369300007-2
# De'Aaron Fox8:2525.40012.500221.000112000117-7
# Kevin Huerter6:1813.33312.500000000000130
# Keegan Murray7:1925.40012.50002.0000110000050
# Harrison Barnes10:2701.00001.00000000210100-2
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Malik Monk5:4224.50012.50012.500000100106-9
# Davion Mitchell3:35111.0000000000100002-2
# Terence Davis4:0701.00001.00000000000010-9
# Neemias Queta2:0702.0000000202000000-7
# Trey Lyles2:07000000000000110-7
# Matthew DellavedovaDid Not Play
# Chimezie MetuDid Not Play
# Richaun HolmesDid Not Play
# KZ OkpalaDid Not Play
# Alex LenDid Not Play
# Team Totals601127.407410.40049.44468147104430
#
#
#
#
#
#
#
#
#
# Sacramento Kings (Q2)
#
#
#
#
#
#
# Sacramento Kings (Q2) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Domantas Sabonis8:4734.750111.00000077210117+5
# De'Aaron Fox8:0924.50001.00000000000114-5
# Kevin Huerter8:3913.33312.50000000100013+7
# Keegan Murray8:2313.33312.50000000000023+15
# Harrison Barnes7:28331.0000046.6670110100110+2
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Malik Monk3:2101.00001.000221.000011100102-1
# Davion Mitchell8:47111.0000000101300002+5
# Terence Davis
# Neemias Queta3:13111.0000000022001002+1
# Trey Lyles3:13000000011000010+1
# Matthew DellavedovaDid Not Play
# Chimezie MetuDid Not Play
# Richaun HolmesDid Not Play
# KZ OkpalaDid Not Play
# Alex LenDid Not Play
# Team Totals601220.60037.42968.750112137213733
#
#
#
#
#
#
#
#
#
# Sacramento Kings (H1)
#
#
#
#
#
#
# Sacramento Kings (H1) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Domantas Sabonis18:4069.667111.00013.333313165101114+3
# De'Aaron Fox16:3449.44413.333221.0001120002211-12
# Kevin Huerter14:5726.33324.50000000100026+7
# Keegan Murray15:4238.37524.50002.000011000028+15
# Harrison Barnes17:5534.75001.00046.66701122011100
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Malik Monk9:0325.40013.33334.750011200208-10
# Davion Mitchell12:22221.0000000101400004+3
# Terence Davis4:0701.00001.00000000000010-9
# Neemias Queta5:2013.3330000224001002-6
# Trey Lyles5:20000000011000120-6
# Matthew DellavedovaDid Not Play
# Chimezie MetuDid Not Play
# Richaun HolmesDid Not Play
# KZ OkpalaDid Not Play
# Alex LenDid Not Play
# Team Totals1202347.489717.4121017.58872027143171163
#
#
#
#
#
#
#
#
#
# Sacramento Kings (Q3)
#
#
#
#
#
#
# Sacramento Kings (Q3) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Domantas Sabonis11:3447.571111.00000112100019+2
# De'Aaron Fox6:4645.800111.000000220000090
# Kevin Huerter6:2013.33312.50000022000013-2
# Keegan Murray3:200000000000000200
# Harrison Barnes11:3403.00001.00012.500022100001+2
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Malik Monk5:4012.50001.00000000200012+6
# Davion Mitchell5:1412.50012.50000000110003+4
# Terence Davis9:0613.33302.00001.000000120002+6
# Neemias Queta0:26000000000000000+2
# Trey Lyles
# Matthew DellavedovaDid Not Play
# Chimezie MetuDid Not Play
# Richaun HolmesDid Not Play
# KZ OkpalaDid Not Play
# Alex LenDid Not Play
# Team Totals601225.480410.40013.3331786300529
#
#
#
#
#
#
#
#
#
# Sacramento Kings (Q4)
#
#
#
#
#
#
# Sacramento Kings (Q4) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Domantas Sabonis10:3023.6670012.500145100025+1
# De'Aaron Fox10:23611.54501.00057.7140112000317-8
# Kevin Huerter10:3002.00002.00002.000101000020+1
# Keegan Murray12:00111.000111.00000000011003-7
# Harrison Barnes
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Malik Monk10:0116.16702.00000000000002-2
# Davion Mitchell3:36000000000000000-4
# Terence Davis1:30000000000010000-8
# Neemias Queta1:30000000000000100-8
# Trey Lyles
# Matthew DellavedovaDid Not Play
# Chimezie MetuDid Not Play
# Richaun HolmesDid Not Play
# KZ OkpalaDid Not Play
# Alex LenDid Not Play
# Team Totals601023.43516.167611.5452573211727
#
#
#
#
#
#
#
#
#
# Sacramento Kings (H2)
#
#
#
#
#
#
# Sacramento Kings (H2) Table
#
#
#
# Basic Box Score Stats
#
#
# Starters
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
#
# Domantas Sabonis22:04610.600111.00012.5002572000314+3
# De'Aaron Fox17:091016.62512.50057.7140332000326-8
# Kevin Huerter16:5015.20014.25002.000123000033-1
# Keegan Murray15:20111.000111.00000000011023-7
# Harrison Barnes11:3403.00001.00012.500022100001+2
#
# Reserves
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# +/-
#
# Malik Monk15:4128.25003.00000000200014+4
# Davion Mitchell8:5012.50012.500000001100030
# Terence Davis10:3613.33302.00001.000000130002-2
# Neemias Queta1:56000000000000100-6
# Trey Lyles
# Matthew DellavedovaDid Not Play
# Chimezie MetuDid Not Play
# Richaun HolmesDid Not Play
# KZ OkpalaDid Not Play
# Alex LenDid Not Play
# Team Totals1202248.458516.312714.5003121595111256
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Table
#
#
#
# Advanced Box Score Stats
#
#
# Starters
# MP
# TS%
# eFG%
# 3PAr
# FTr
# ORB%
# DRB%
# TRB%
# AST%
# STL%
# BLK%
# TOV%
# USG%
# ORtg
# DRtg
# BPM
#
#
# Domantas Sabonis40:44.660.684.105.26310.749.327.726.71.10.04.522.414111210.8
# De'Aaron Fox33:43.639.600.200.3602.613.27.311.40.00.06.537.81211223.8
# Kevin Huerter31:47.379.409.727.1822.77.04.63.70.00.00.015.485124-10.7
# Keegan Murray31:02.557.611.556.2220.03.61.60.01.52.40.013.1107120-3.1
# Harrison Barnes29:29.523.429.2861.1430.011.45.012.23.10.08.716.1109116-1.0
#
# Reserves
# MP
# TS%
# eFG%
# 3PAr
# FTr
# ORB%
# DRB%
# TRB%
# AST%
# STL%
# BLK%
# TOV%
# USG%
# ORtg
# DRtg
# BPM
#
# Malik Monk24:51.407.346.462.3080.04.52.020.70.00.011.927.885125-10.1
# Davion Mitchell21:04.875.875.500.0004.10.02.329.92.20.00.07.81911219.0
# Terence Davis14:43.225.250.750.2500.00.00.07.89.30.00.012.459105-2.2
# Neemias Queta7:16.333.333.000.00024.030.727.00.00.010.325.022.779112-10.0
# Trey Lyles5:200.020.99.20.00.00.0100.07.70120-21.2
# Matthew DellavedovaDid Not Play
# Chimezie MetuDid Not Play
# Richaun HolmesDid Not Play
# KZ OkpalaDid Not Play
# Alex LenDid Not Play
# Team Totals240.548.537.347.32618.274.442.951.17.63.16.9100.0112.6118.3
#
#
#
#
#
#
#
# Inactive: CHO Cody Martin, Bryce McGowens, Terry Rozier, Dennis Smith Jr., Mark Williams   SAC Keon Ellis, Chima Moneke
# Officials: John Butler, Courtney Kirkland, Phenizee Ransom
# Attendance: 17,803
# Time of Game: 2:24
#
#
#
#
# Team and League Schedules
#
# Dec 19, 2022 NBA Scores & Boxes
#
# Charlotte Hornets Schedule
# Sacramento Kings Schedule
# 2022-23 NBA Schedule & Results
#
#
#
#
# Welcome  · Your Account
# Logout
# Login
# Create Account
#
# You are here: BBR Home Page  > Box Scores  > Charlotte Hornets at Sacramento Kings Box Score, December 19, 2022
#
#
#
#
# Full Site Menu
# Return to Top
#
#
#
#
#
# Players
# In the News:
#
# L. James,
# K. Durant,
# J. Embiid,
# J. Harden,
# S. Curry,
# L. Dončić
#
# ...
#
# All-Time Greats:
#
# E. Hayes,
# J. Stockton,
# H. Olajuwon,
# W. Chamberlain,
# D. Schayes,
# J. Havlicek
#
# ...
#
# Active Greats:
#
# L. James,
# G. Antetokounmpo,
# C. Paul,
# J. Harden,
# S. Curry,
# K. Durant
#
# ...
#
#
#
# Teams
#
#
# Atlantic:
#       Toronto,
#       Boston,
#       New York,
#       Brooklyn,
#       Philadelphia
#
#
# Central:
#       Cleveland,
#       Indiana,
#       Detroit,
#       Chicago,
#       Milwaukee
#
#
# Southeast:
#       Miami,
#       Atlanta,
#       Charlotte,
#       Washington,
#       Orlando
#
#
# Northwest:
#       Oklahoma City,
#       Portland,
#       Utah,
#       Denver,
#       Minnesota
#
#
# Pacific:
#       Golden State,
#       Los Angeles Clippers,
#       Sacramento,
#       Phoenix,
#       Los Angeles Lakers
#
#
# Southwest:
#       San Antonio,
#       Dallas,
#       Memphis,
#       Houston,
#       New Orleans
#
#
#
#
# Seasons
#
#
# 2022-23,
# 2021-22,
# 2020-21,
# 2019-20,
# 2018-19,
# 2017-18,
# 2016-17,
#
#
#
#
# Leaders
#
# Season Points,
#       Career Rebounds,
#       Active Assists,
#       Yearly Steals,
#       Progressive Blocks
#       ...
#
#
#       Or, view "Trailers" for Season Field Goal Pct, or Career Blocks Per Game
#
#
#
# NBA Scores
#
# Yesterday's Games and Scores from any date in BAA/NBA or ABA history
#
#
#
#
# NBA Schedules
#
# Team Schedules and League Schedules
#
#
#
#
#
# NBA Standings
#
# Today's Standings and Standings for any date in history
#
#
#
#
# Stathead
# Player Finders:
#       Season Finder,
#       Game Finder,
#       Streak Finder,
#       Span Finder
#
# Team Finders:
#       Season Finder,
#       Game Finder,
#       Streak Finder,
#       Score Finder,
#       Rivalry Finder
#
# Other Finders:
#       Draft Finder,
#       Head-to-Head Finder,
#       Player Comparison Finder
#
#
#
# Coaches
#
# Richie Guerin,
#       Rudy Tomjanovich,
#       Jim O'Brien,
#       Mike Fratello,
#       Alvin Gentry
#
#
#
# Awards
#
# NBA MVP,
#       All-NBA,
#       Defensive Player of the Year,
#       Rookie of the Year,
#       All-Rookie,
#       Hall of Fame
#       ...
#
#
#
# NBA Contracts
#
# Main Index,
#       Team Payrolls,
#       Player Contracts,
#       Glossary,
#       ...
#
#
#
# Playoffs
#
# 2022 NBA Playoffs,
#       2021 NBA Playoffs,
#       2020 NBA Playoffs,
#       2019 NBA Playoffs,
#       2018 NBA Playoffs,
#       2017 NBA Playoffs,
#       Playoffs Series History
#       ...
#
#
#
# All-Star Games
#
# 2022 All-Star Game,
#       2021 All-Star Game,
#       2020 All-Star Game,
#       2019 All-Star Game,
#       2018 All-Star Game
#       ...
#
#
#
# NBA Draft
#
# 2022 Draft,
#       2021 Draft,
#       2020 Draft,
#       2019 Draft,
#       2018 Draft,
#       2017 Draft,
#       ...
#
#
#
# Frivolities
#
# Birthdays,
#       Colleges,
#       High Schools,
#       Milestone Watch
#       ...
#
#
#
# Executives
#
# R.C. Buford,
#       Wayne Embry,
#       Stan Kasten,
#       Danny Ainge,
#       Don Nelson
#       ...
#
#
#
# Referees
#
# Joe Forte,
#       Tony Brothers,
#       Dan Crawford,
#       Ron Olesiak,
#       David Jones
#       ...
#
#
#
# G League Stats
#
# Players,
#       Teams,
#       Seasons,
#       Leaders,
#       Awards
#       ...
#
#
#
# International Basketball Stats
#
# Players,
#       Teams,
#       Seasons,
#       Leaders,
#       Awards
#       ...
#
#
#
# WNBA
#
# Players,
#       Teams,
#       Seasons,
#       Leaders,
#       Awards,
#       All-Star Games
#       ...
#
#
#
# NBL
#
# Players,
#       Teams,
#       Seasons,
#       Leaders,
#       Awards
#       ...
#
#
#
# About
#
# Glossary,
#       Contact and Media Information,
#       Frequently Asked Questions about the NBA, WNBA and Basketball
#       ...
#
#
#
#
#
# Basketball-Reference.com Blog and Articles
#
#
#
#
# We're Social...for Statheads
#
#
#
#
#
#
#
#
#
#
#
#
# Every Sports Reference Social Media Account
# Site Last Updated: Sunday, January  8,  4:48AM
#
# Question, Comment, Feedback, or Correction?
# Subscribe to our Free Email Newsletter
# This Month in Sports ReferenceFind out when we add a feature or make a change
# Do you have a sports website? Or write about sports? We have tools and resources that can help you use sports data.  Find out more.
#
#
#
# FAQs, Tip & Tricks
#
#
#
# Tips and Tricks from our Blog.
# Do you have a blog? Join our linker program.
# Watch our How-To Videos to Become a Stathead
# Subscribe to Stathead and get access to more data than you can imagine
#
#
#
# All logos are the trademark & property of their owners and not Sports Reference LLC.  We present them here for purely educational purposes.
# 				Our reasoning for presenting offensive logos.
#
#
# 					Logos were compiled by the amazing SportsLogos.net.
#
#
# Data Provided By
#
# 	the official stats partner of the NBA.
#
# Copyright © 2000-2023 Sports Reference LLC. All rights reserved.
# The SPORTS REFERENCE and STATHEAD trademarks are owned exclusively by Sports Reference LLC. Use without license or authorization is expressly prohibited.
#
#
#
#
#
#  Sports Reference ®
# Baseball
# Football (college)
# Basketball (college)
# Hockey
# Futebol
# Blog
# Stathead ®
#
#
# About •
#   Conditions & Terms of Service •
#   Advertise With Us
#  •
#   Jobs at SR
#
# Sports Reference Purpose: We will be the trusted source of information and tools that inspire and empower users to enjoy, understand, and share the sports they love.
#
# Privacy Policy •
#   Gambling Revenue Policy •
#   Accessibility Policy •
#   Use of Data
